# %%
import pandas as pd

# %%
df_small = pd.read_sql(
    """
    SELECT
    *
    FROM
    country;
    ""","postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)
df_small.head()
# Out:
#   code                  name      continent                     region  \
# 0  AFG           Afghanistan           Asia  Southern and Central Asia
# 1  NLD           Netherlands         Europe             Western Europe
# 2  ANT  Netherlands Antilles  North America                  Caribbean
# 3  ALB               Albania         Europe            Southern Europe
# 4  DZA               Algeria         Africa            Northern Africa
#
#    surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0      652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 2         800.0         NaN      217000             74.7    1941.0       NaN
# 3       28748.0      1912.0     3401200             71.6    3205.0    2500.0
# 4     2381740.0      1962.0    31471000             69.7   49982.0   46966.0
#
#               local_name                               government_form  \
# 0  Afganistan/Afqanestan                               Islamic Emirate
# 1              Nederland                       Constitutional Monarchy
# 2   Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
# 3              Shqipëria                                      Republic
# 4     Al-Jazair/Algérie                                      Republic
#
#           head_of_state  capital code2
# 0         Mohammad Omar      1.0    AF
# 1               Beatrix      5.0    NL
# 2               Beatrix     33.0    AN
# 3        Rexhep Mejdani     34.0    AL
# 4  Abdelaziz Bouteflika     35.0    DZ

# %% [markdown]
# # Новый раздел

# %% [markdown]
# # Новый раздел

# %%
df = pd.read_sql(
    """
    SELECT
    *
    FROM
    country_language;
    ""","postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)
df.head(10
        )
# Out:
#   country_code        language  is_official  percentage
# 0          AFG          Pashto         True        52.4
# 1          NLD           Dutch         True        95.6
# 2          ANT      Papiamento         True        86.2
# 3          ALB       Albaniana         True        97.9
# 4          DZA          Arabic         True        86.0
# 5          ASM          Samoan         True        90.6
# 6          AND         Spanish        False        44.6
# 7          AGO       Ovimbundu        False        37.2
# 8          AIA         English         True         0.0
# 9          ATG  Creole English        False        95.7

# %%
df_country = pd.read_sql(
    """
    SELECT
     *
    FROM
     country_language ctrl
    INNER JOIN
     country ctr
     ON
     ctrl.country_code = ctr.code
    WHERE
     is_official = True
    """,    "postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
  )
df_country.head(10)
# Out:
#   country_code    language  is_official  percentage code  \
# 0          AFG      Pashto         True        52.4  AFG
# 1          NLD       Dutch         True        95.6  NLD
# 2          ANT  Papiamento         True        86.2  ANT
# 3          ALB   Albaniana         True        97.9  ALB
# 4          DZA      Arabic         True        86.0  DZA
# 5          ASM      Samoan         True        90.6  ASM
# 6          AIA     English         True         0.0  AIA
# 7          ARE      Arabic         True        42.0  ARE
# 8          ARG     Spanish         True        96.8  ARG
# 9          ARM    Armenian         True        93.4  ARM
#
#                    name      continent                     region  \
# 0           Afghanistan           Asia  Southern and Central Asia
# 1           Netherlands         Europe             Western Europe
# 2  Netherlands Antilles  North America                  Caribbean
# 3               Albania         Europe            Southern Europe
# 4               Algeria         Africa            Northern Africa
# 5        American Samoa        Oceania                  Polynesia
# 6              Anguilla  North America                  Caribbean
# 7  United Arab Emirates           Asia                Middle East
# 8             Argentina  South America              South America
# 9               Armenia           Asia                Middle East
#
#    surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0      652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 2         800.0         NaN      217000             74.7    1941.0       NaN
# 3       28748.0      1912.0     3401200             71.6    3205.0    2500.0
# 4     2381740.0      1962.0    31471000             69.7   49982.0   46966.0
# 5         199.0         NaN       68000             75.1     334.0       NaN
# 6          96.0         NaN        8000             76.1      63.2       NaN
# 7       83600.0      1971.0     2441000             74.1   37966.0   36846.0
# 8     2780400.0      1816.0    37032000             75.1  340238.0  323310.0
# 9       29800.0      1991.0     3520000             66.4    1813.0    1627.0
#
#                            local_name  \
# 0               Afganistan/Afqanestan
# 1                           Nederland
# 2                Nederlandse Antillen
# 3                           Shqipëria
# 4                  Al-Jazair/Algérie
# 5                       Amerika Samoa
# 6                            Anguilla
# 7  Al-Imarat al-´Arabiya al-Muttahida
# 8                           Argentina
# 9                            Hajastan
#
#                                 government_form                head_of_state  \
# 0                               Islamic Emirate                Mohammad Omar
# 1                       Constitutional Monarchy                      Beatrix
# 2  Nonmetropolitan Territory of The Netherlands                      Beatrix
# 3                                      Republic               Rexhep Mejdani
# 4                                      Republic         Abdelaziz Bouteflika
# 5                                  US Territory               George W. Bush
# 6                 Dependent Territory of the UK                 Elisabeth II
# 7                            Emirate Federation  Zayid bin Sultan al-Nahayan
# 8                              Federal Republic           Fernando de la Rúa
# 9                                      Republic             Robert Kotarjan
#
#    capital code2
# 0      1.0    AF
# 1      5.0    NL
# 2     33.0    AN
# 3     34.0    AL
# 4     35.0    DZ
# 5     54.0    AS
# 6     62.0    AI
# 7     65.0    AE
# 8     69.0    AR
# 9    126.0    AM

# %%
df_merge = df.merge(df_small, left_on='country_code', right_on='code', how='inner')
df_merge.head()
# Out:
#   country_code    language  is_official  percentage code         name  \
# 0          AFG      Pashto         True        52.4  AFG  Afghanistan
# 1          AFG        Dari         True        32.1  AFG  Afghanistan
# 2          AFG       Uzbek        False         8.8  AFG  Afghanistan
# 3          AFG  Turkmenian        False         1.9  AFG  Afghanistan
# 4          AFG     Balochi        False         0.9  AFG  Afghanistan
#
#   continent                     region  surface_area  indep_year  population  \
# 0      Asia  Southern and Central Asia      652090.0      1919.0    22720000
# 1      Asia  Southern and Central Asia      652090.0      1919.0    22720000
# 2      Asia  Southern and Central Asia      652090.0      1919.0    22720000
# 3      Asia  Southern and Central Asia      652090.0      1919.0    22720000
# 4      Asia  Southern and Central Asia      652090.0      1919.0    22720000
#
#    life_expectancy     gnp  gnp_old             local_name  government_form  \
# 0             45.9  5976.0      NaN  Afganistan/Afqanestan  Islamic Emirate
# 1             45.9  5976.0      NaN  Afganistan/Afqanestan  Islamic Emirate
# 2             45.9  5976.0      NaN  Afganistan/Afqanestan  Islamic Emirate
# 3             45.9  5976.0      NaN  Afganistan/Afqanestan  Islamic Emirate
# 4             45.9  5976.0      NaN  Afganistan/Afqanestan  Islamic Emirate
#
#    head_of_state  capital code2
# 0  Mohammad Omar      1.0    AF
# 1  Mohammad Omar      1.0    AF
# 2  Mohammad Omar      1.0    AF
# 3  Mohammad Omar      1.0    AF
# 4  Mohammad Omar      1.0    AF

# %%
df_merge.query('is_official == True')
# Out:
#     country_code    language  is_official  percentage code  \
# 0            AFG      Pashto         True        52.4  AFG
# 1            AFG        Dari         True        32.1  AFG
# 5            NLD       Dutch         True        95.6  NLD
# 9            ANT  Papiamento         True        86.2  ANT
# 11           ANT       Dutch         True         0.0  ANT
# ..           ...         ...          ...         ...  ...
# 957          EST    Estonian         True        65.3  EST
# 962          USA     English         True        86.2  USA
# 974          VIR     English         True        81.7  VIR
# 977          UMI     English         True         0.0  UMI
# 980          ZWE     English         True         2.2  ZWE
#
#                                      name      continent  \
# 0                             Afghanistan           Asia
# 1                             Afghanistan           Asia
# 5                             Netherlands         Europe
# 9                    Netherlands Antilles  North America
# 11                   Netherlands Antilles  North America
# ..                                    ...            ...
# 957                               Estonia         Europe
# 962                         United States  North America
# 974                  Virgin Islands, U.S.  North America
# 977  United States Minor Outlying Islands        Oceania
# 980                              Zimbabwe         Africa
#
#                         region  surface_area  indep_year  population  \
# 0    Southern and Central Asia      652090.0      1919.0    22720000
# 1    Southern and Central Asia      652090.0      1919.0    22720000
# 5               Western Europe       41526.0      1581.0    15864000
# 9                    Caribbean         800.0         NaN      217000
# 11                   Caribbean         800.0         NaN      217000
# ..                         ...           ...         ...         ...
# 957           Baltic Countries       45227.0      1991.0     1439200
# 962              North America     9363520.0      1776.0   278357000
# 974                  Caribbean         347.0         NaN       93000
# 977       Micronesia/Caribbean          16.0         NaN           0
# 980             Eastern Africa      390757.0      1980.0    11669000
#
#      life_expectancy        gnp    gnp_old  \
# 0               45.9     5976.0        NaN
# 1               45.9     5976.0        NaN
# 5               78.3   371362.0   360478.0
# 9               74.7     1941.0        NaN
# 11              74.7     1941.0        NaN
# ..               ...        ...        ...
# 957             69.5     5328.0     3371.0
# 962             77.1  8510700.0  8110900.0
# 974             78.1        0.0        NaN
# 977              NaN        0.0        NaN
# 980             37.8     5951.0     8670.0
#
#                                local_name  \
# 0                   Afganistan/Afqanestan
# 1                   Afganistan/Afqanestan
# 5                               Nederland
# 9                    Nederlandse Antillen
# 11                   Nederlandse Antillen
# ..                                    ...
# 957                                 Eesti
# 962                         United States
# 974   Virgin Islands of the United States
# 977  United States Minor Outlying Islands
# 980                              Zimbabwe
#
#                                   government_form     head_of_state  capital  \
# 0                                 Islamic Emirate     Mohammad Omar      1.0
# 1                                 Islamic Emirate     Mohammad Omar      1.0
# 5                         Constitutional Monarchy           Beatrix      5.0
# 9    Nonmetropolitan Territory of The Netherlands           Beatrix     33.0
# 11   Nonmetropolitan Territory of The Netherlands           Beatrix     33.0
# ..                                            ...               ...      ...
# 957                                      Republic      Lennart Meri   3791.0
# 962                              Federal Republic    George W. Bush   3813.0
# 974                                  US Territory    George W. Bush   4067.0
# 977                 Dependent Territory of the US    George W. Bush      NaN
# 980                                      Republic  Robert G. Mugabe   4068.0
#
#     code2
# 0      AF
# 1      AF
# 5      NL
# 9      AN
# 11     AN
# ..    ...
# 957    EE
# 962    US
# 974    VI
# 977    UM
# 980    ZW
#
# [238 rows x 19 columns]
